# %% [markdown]
# # Assignment 5 Questions

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# #### Task 1:
#
# Read the dataset from the bellow link
#
# url = https://raw.githubusercontent.com/hadley/data-baby-names/master/baby-names.csv

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import time
import requests
import io

# %%
url = 'https://raw.githubusercontent.com/hadley/data-baby-names/master/baby-names.csv'
s=requests.get(url).content
df=pd.read_csv(io.StringIO(s.decode('utf-8')))
df.head()
# Out:
#    year     name   percent  sex
# 0  1880     John  0.081541  boy
# 1  1880  William  0.080511  boy
# 2  1880    James  0.050057  boy
# 3  1880  Charles  0.045167  boy
# 4  1880   George  0.043292  boy

# %% [markdown]
# Questions

# %% [markdown]
# 1. Delete unnamed columns

# %%
df.drop(df.columns[df.columns.str.contains('unnamed',case = False)],axis = 1, inplace = True)

# %% [markdown]
# 2. Show the distribution of male and female

# %%
y=df.sex
ax=sns.countplot(y, label='sex')
B,M=y.value_counts()
print('Number of B tumor',B)
print('Number of M tumor',M)
# Out:
# Number of B tumor 129000
# Number of M tumor 129000

# %%
(len(df.loc[df['sex']=='boy']),len(df.loc[df['sex']=='girl']))
# Out:
# (129000, 129000)

# %% [markdown]
# 3. Show the top 5 most preferred names

# %%
df['name'].value_counts()[:5].sort_values(ascending=False)
# Out:
# Jessie       258
# Leslie       247
# Jean         244
# Guadalupe    244
# Lee          240
# Name: name, dtype: int64

# %% [markdown]
# 4. What is the median name occurence in the dataset

# %%
#get the median count of names 
print(df['name'].value_counts().median())
# printing median names with respect to the value counts
print(df.name.value_counts(ascending=False)[df.name.value_counts(ascending=False) == 19.0].index)
# Out:
# 19.0
# Index(['Lew', 'Wayman', 'Jaylen', 'Mariela', 'Alline', 'Heaven', 'Genie',
#        'Elberta', 'Johny', 'Ami', 'Kenyatta', 'Adrain', 'Elois', 'Oakley',
#        'Marylin', 'Tiny', 'Brooklyn', 'Nataly', 'Alba', 'Windell', 'Harrell',
#        'Shaina', 'Teena', 'Mannie', 'Haleigh', 'Clemens', 'Oneal', 'Talon',
#        'Laci', 'Dulce', 'Rube', 'Imani', 'Dionne', 'Marilou', 'Eligah',
#        'Misael', 'Nakia', 'Alena', 'Corinna', 'Raina', 'Salina', 'Lavera',
#        'Doshie', 'Trena', 'Kristoffer', 'Tisha', 'Zenobia', 'Dimple', 'Brynn',
#        'Chiquita', 'Kane', 'Bobbye', 'Aidan', 'Lum', 'Juli', 'Luciano',
#        'Camden', 'Fabiola', 'Phoenix', 'Giuseppe', 'Eliana', 'Brien',
#        'Shakira', 'Monnie', 'Newt', 'Nonie', 'Yasmine', 'Rosendo', 'Olan',
#        'Tawana', 'Shelli', 'Vonnie', 'Daria', 'Milagros'],
#       dtype='object')

# %% [markdown]
# 5. Distribution of male and female born count by states

# %%
#states column not available in df

# %% [markdown]
# #### Task 2:
#
# We have the min and max temperatures in a city In India for each months of the year. We
# would like to find a function to describe this and show it graphically, the dataset given below.
#
#     Task:
#     1. fitting it to the periodic function
#     2. plot the fit
#
#     Data
#     Max = 39, 41, 43, 47, 49, 51, 45, 38, 37, 29, 27, 25
#     Min = 21, 23, 27, 28, 32, 35, 31, 28, 21, 19, 17, 18

# %%
data={'Max':[39, 41, 43, 47, 49, 51, 45, 38, 37, 29, 27, 25],
     'Min':[21, 23, 27, 28, 32, 35, 31, 28, 21, 19, 17, 18]}
df=pd.DataFrame(data)
plt.plot(range(12),df.Max)
plt.plot(range(12),df.Min)
plt.grid()
plt.xlim(0,12)
plt.xlabel('Months')
plt.ylabel('Temperature') 
plt.title('Annual temperature variation plot ')
plt.show()
# Out:
# No handles with labels found to put in legend.
